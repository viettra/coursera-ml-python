# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from run_ex1 import Dataset

# %%
a = np.eye(5)

# %%
path = 'ex1'

# %%
data = [x for x in os.listdir(path) if not x.startswith('.')]
data

# %%
data1 = 'ex1/ex1data1.txt'
data2 = 'ex1/ex1data2.txt'

# %%
with open(data1, 'r') as f:
    content = f.read().splitlines()
#content = np.asarray(content)
# X = content[0,:]
# y = content[1,:]
# print('X shape: {}\t y shape: {}'.format(X.shape, y.shape))

# %%
X = []
y = []
for line in content:
    line = line.split(',')
    X.append(float(line[0]))
    y.append(float(line[1]))
X = np.asarray(X)
y = np.asarray(y)

# %%
# %matplotlib inline
plt.plot(X, y, 'rx')
plt.xlabel('Populations of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.show()

# %%
a = Dataset().plot_data()
# Out:
# plotting data...

# %%
a.plot_data()

# %%
Dataset().plot_data()
# Out:
# plotting data...
